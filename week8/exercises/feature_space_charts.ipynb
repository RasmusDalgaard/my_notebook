# %%
import feature_space

feature_space.plot_babies(feature_space.generate_babies(10))
# Out:
# [(48, 3.8, 5), (50, 3.2, 10), (51, 3.4, 7), (52, 2.8, 4), (52, 2.6, 8), (43, 2.7, 3), (44, 2.4, 9), (51, 3.4, 3), (51, 2.7, 6), (51, 3.2, 2)]
