# %%
import handin_02
import matplotlib.pyplot as plt

books = handin_02.womens_fiction()
titles = list(books.keys())
prices = list(books.values())
plt.ylabel('Price in £')
plt.xticks(range(len(books)), titles, rotation='vertical')
plt.bar(range(len(books)), prices, align='edge', width=0.75)
# Out:
# <BarContainer object of 17 artists>
